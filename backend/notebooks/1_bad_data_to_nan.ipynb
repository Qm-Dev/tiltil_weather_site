# %%
import pandas as pd
import numpy as np
import os
from dotenv import load_dotenv

load_dotenv(dotenv_path="../.env")
# Out:
# True

# %%
df = pd.read_csv("historic2.csv", sep=";", low_memory=False)
df
# Out:
#             Date   Time Avg Temp Hi Temp Low Temp Out Hum Dew Pt  Wind Speed  \
# 0       08-01-08  14:14     32.7    32.7     32.7      24    9.5         4.8
# 1       08-01-08  14:15     32.8    32.8     32.7      24    9.6         4.8
# 2       08-01-08  14:16     32.8    32.8     32.8      23    9.0         8.0
# 3       08-01-08  14:17     32.8    32.8     32.8      23    9.0         3.2
# 4       08-01-08  14:18     32.8    32.8     32.8      23    8.9         1.6
# ...          ...    ...      ...     ...      ...     ...    ...         ...
# 645922  18-05-26  18:45     15.6    16.7     15.6      18   -8.7         1.6
# 645923  18-05-26  19:00     14.8    15.6     14.8      19   -8.6         1.6
# 645924  18-05-26  19:15     13.9    14.8     13.9      20   -8.7         0.0
# 645925  18-05-26  19:30     13.1    13.9     13.1      20   -9.4         0.0
# 645926  18-05-26  19:45     12.6    13.1     12.6      21   -9.2         1.6
#
#        Wind Direction  Wind Run  ...  In Hum In Dew In Heat In EMC  \
# 0                  SE      0.08  ...      40    ---     ---    ---
# 1                   S      0.08  ...      41   13.9    28.0   7.69
# 2                 ESE      0.13  ...      40   13.6    28.0   7.55
# 3                 ESE      0.05  ...      40   13.6    28.0   7.55
# 4                  NE      0.03  ...      40   13.6    28.0   7.55
# ...               ...       ...  ...     ...    ...     ...    ...
# 645922            SSW      0.40  ...      28   -0.7    16.0   5.96
# 645923             SW      0.40  ...      28   -0.7    15.9   5.96
# 645924             SW      0.00  ...      27   -1.3    15.7   5.85
# 645925             SW      0.00  ...      27   -1.4    15.6   5.85
# 645926             SW      0.40  ...      27   -1.6    15.4   5.85
#
#        In Air Density    ET Wind Samp  Wind Tx  ISS Recept Arc. Int.
# 0                 ---  0.00         8        1        34.8         1
# 1              1.1484  0.00        24        1       100.0         1
# 2              1.1482  0.00        23        1       100.0         1
# 3              1.1482  0.00        23        1       100.0         1
# 4              1.1482  0.00        24        1       100.0         1
# ...               ...   ...       ...      ...         ...       ...
# 645922         1.2076  0.00       352        1       100.0        15
# 645923         1.2079  0.05       348        1       100.0        15
# 645924         1.2090  0.00       351        1       100.0        15
# 645925         1.2097  0.00       351        1       100.0        15
# 645926         1.2106  0.00       352        1       100.0        15
#
# [645927 rows x 38 columns]

# %%
dt = pd.to_datetime(df["Date"] + " " + df["Time"], format="%d-%m-%y %H:%M")
df.insert(0, "record_date", dt)
df.drop(columns=["Date", "Time"], inplace=True)

# Nulls
df.replace(["---", "------"], np.nan, inplace=True)

# Renaming
original = os.getenv("CSV_ORIGINAL_HEADERS", "").split(",")
original = [h for h in original if h not in ["Date", "Time"]]
expected = os.getenv("EXPECTED_CSV_HEADERS", "").split(",")
expected_mapping = [h for h in expected if h != "record_date"]
mapping_dict = dict(zip(original, expected_mapping))

df.rename(columns=mapping_dict, inplace=True)

# %%
df.to_csv("historic_with_nulls.csv", index=False)
